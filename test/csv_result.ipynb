# %%
import os
import sys

import lightning as L
import torch

sys.path.append(os.path.abspath('../'))

# %%
"""Modules for presenting the training results."""

import os

import pandas as pd
import torch

from source.utils.path import root_path

name = 'ClassicalMPGNN-go1024_gh1024_gl4-Maxptc4_N100-rnd_0'

csv_dir = os.path.join(root_path, 'training_logs', 'CSVLogger')

last_version = os.listdir(os.path.join(csv_dir, name))[-1]

csv_path = os.path.join(csv_dir, name, last_version, 'metrics.csv')

df = pd.read_csv(csv_path)

train_acc = df.dropna(subset=['train_accuracy'])['train_accuracy'].to_numpy()
valid_acc = df.dropna(subset=['train_accuracy', 'valid_accuracy'])['valid_accuracy'].to_numpy()

df.keys()
df
# Out:
#     epoch  epoch_time  step  train_accuracy  train_auc  train_loss  \
# 0     NaN         NaN     0             NaN        NaN         NaN
# 1     NaN         NaN     1             NaN        NaN         NaN
# 2     NaN         NaN     2             NaN        NaN         NaN
# 3     0.0         NaN     2             NaN        NaN         NaN
# 4     0.0    0.368800     2        0.306667   0.466967         NaN
# 5     NaN         NaN     3             NaN        NaN         NaN
# 6     NaN         NaN     4             NaN        NaN         NaN
# 7     NaN         NaN     5             NaN        NaN         NaN
# 8     1.0         NaN     5             NaN        NaN         NaN
# 9     1.0    0.134308     5        0.300000   0.499467         NaN
# 10    NaN         NaN     6             NaN        NaN         NaN
# 11    NaN         NaN     7             NaN        NaN         NaN
# 12    NaN         NaN     8             NaN        NaN         NaN
# ...
